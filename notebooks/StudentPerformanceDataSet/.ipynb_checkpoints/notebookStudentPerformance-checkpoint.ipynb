# %% [markdown]
# EDA - Student Performance

# %%
#Libraries
import numpy as np
import pandas as pd
import sklearn
from sklearn import linear_model
from sklearn.utils import shuffle

# %%
#import data

data = pd.read_csv('./data/student/student-mat.csv', sep=';')

# %%
#some elements
data.head(5)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
# school        395 non-null object
# sex           395 non-null object
# age           395 non-null int64
# address       395 non-null object
# famsize       395 non-null object
# Pstatus       395 non-null object
# Medu          395 non-null int64
# Fedu          395 non-null int64
# Mjob          395 non-null object
# Fjob          395 non-null object
# reason        395 non-null object
# guardian      395 non-null object
# traveltime    395 non-null int64
# studytime     395 non-null int64
# failures      395 non-null int64
# schoolsup     395 non-null object
# famsup        395 non-null object
# paid          395 non-null object
# activities    395 non-null object
# nursery       395 non-null object
# higher        395 non-null object
# internet      395 non-null object
# romantic      395 non-null object
# famrel        395 non-null int64
# ...

# %%
data.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
#columns
data.columns.values

columsFeatures = ['G1','G2','G3','failures','studytime','absences'] #Used this features based on reference [1]
columLabel = 'G3'

#selecting data features
data = data[columsFeatures]; data
# Out:
#      G1  G2  G3  failures  studytime  absences
# 0     5   6   6         0          2         6
# 1     5   5   6         0          2         4
# 2     7   8  10         3          2        10
# 3    15  14  15         0          3         2
# 4     6  10  10         0          2         4
# ..   ..  ..  ..       ...        ...       ...
# 390   9   9   9         2          2        11
# 391  14  16  16         0          1         3
# 392  10   8   7         3          1         3
# 393  11  12  10         0          1         0
# 394   8   9   9         0          1         5
#
# [395 rows x 6 columns]

# %%
x = np.array(data.drop([columLabel],axis='columns')) # array com as features ['G1','G2','failures','studytime','absences']
y = np.array(data[columLabel]) # array com label [G3]

# %%
#Applying Linear_model_Regression

xTrain, xTest, yTrain, yTest = sklearn.model_selection.train_test_split(x,y, test_size=0.1)
# Spliting the data in train and test, selecting 10% of data to test and 90% to train.

linear = linear_model.LinearRegression()
linear.fit(xTrain, yTrain)
accuracy = linear.score(xTest,yTest)

# %%
# Some print out after applying Linear_model_Regression

print("Accuracy: ", accuracy)
print("Some info about model:")
print("Coefficient: \n",linear.coef_)
print("Intercept: \n", linear.intercept_)
# Out:
# Accuracy:  0.8825736766452492
# Some info about model:
# Coefficient:
#  [ 0.15233413  0.97614621 -0.28783212 -0.19341652  0.03719119]
# Intercept:
#  -1.4206211773910908

# %%
# Comparing preticted, using de model build above, and the real values

compare = []

predicted = linear.predict(xTest) #Applying de model constructed above in data split to teste, dataTest.

for i in range(0, len(xTest)):
    compare.append(["{0:.3f}".format(predicted[i]), xTest[i],yTest[i]])

# where: 
#  predicted[i], represent the value predicted by model build above, modelLinearRegression.
#  xTest[i], represent the values of features used by model to predicted yTest.
#  yTest[i], represent the real value.
   
    
    
    
compareDataFrame = pd.DataFrame(compare, columns=['Predicted', 'FeaturesTest', 'RealValue/LabelTest'])
compareDataFrame
# Out:
#    Predicted        FeaturesTest  RealValue/LabelTest
# 0      8.423     [9, 9, 0, 2, 2]                   10
# 1      8.840     [9, 9, 0, 1, 8]                   10
# 2     15.651   [16, 15, 0, 1, 5]                   16
# 3      6.393     [8, 7, 0, 2, 4]                    6
# 4     10.121   [11, 10, 0, 1, 8]                   10
# 5     18.081   [16, 18, 0, 3, 2]                   18
# 6     11.954  [11, 12, 0, 2, 10]                   13
# 7      4.767     [8, 6, 2, 2, 2]                    5
# 8     10.910   [13, 11, 0, 2, 0]                   10
# 9      7.220     [8, 8, 0, 2, 0]                    0
# 10    10.985   [13, 11, 0, 2, 2]                   11
# 11    10.303  [12, 10, 0, 2, 14]                   11
# 12     6.438     [8, 7, 0, 1, 0]                    6
# 13     6.210    [6, 7, 1, 2, 15]                    8
# 14    15.644  [16, 15, 0, 2, 10]                   15
# 15    15.681  [16, 15, 0, 2, 11]                   15
# ...

# %% [markdown]
# Fontes:
#
#     [1]https://techwithtim.net/tutorials/machine-learning-python/linear-regression/
#     [2]http://archive.ics.uci.edu/ml/datasets/Student+Performance#
#     [3]https://www.kaggle.com/startupsci/titanic-data-science-solutions

# %% [markdown]
# Citations:
#
# P. Cortez and A. Silva. Using Data Mining to Predict Secondary School Student Performance. In A. Brito and J. Teixeira Eds., Proceedings of 5th FUture BUsiness TEChnology Conference (FUBUTEC 2008) pp. 5-12, Porto, Portugal, April, 2008, EUROSIS, ISBN 978-9077381-39-7.
